# %%
import pandas as pd

# %%
df_error = pd.read_csv('error_ma_2.csv')
df_pdll = pd.read_csv('villes_error_1.csv')

# %%
# 1. Obtenir les URLs uniques du premier DataFrame
urls_a_filtrer = df_error['url'].unique()

# 2. Filtrer le second DataFrame en utilisant isin()
df_filtre = df_pdll[df_pdll['url'].isin(urls_a_filtrer)]

#Enlever les majuscules
df_filtre['url'] = df_filtre['url'].str.lower()

# Afficher le résultat
df_filtre
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_21252\605700948.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtre['url'] = df_filtre['url'].str.lower()
#      Unnamed: 0  #Code_commune_INSEE                         Lib_MA  \
# 0         17928                44009                 BASSE GOULAINE
# 1         17939                44020                     BOUGUENAIS
# 2         17940                44020                     LES COUETS
# 3         17957                44035          LA CHAPELLE SUR ERDRE
# 4         17974                44052                         DONGES
# 5         17978                44056                FAY DE BRETAGNE
# 6         17986                44066       GRANDCHAMP DES FONTAINES
# ...

# %%
# Vérifier si toutes les URLs sont en minuscules
est_tout_minuscule = df_filtre['url'].str.islower().all()

print(f"Toutes les URLs sont-elles en minuscules ? {est_tout_minuscule}")
# Out:
# Toutes les URLs sont-elles en minuscules ? True

# %%
df_filtre.to_csv('villes_error_2.csv', index=False)
