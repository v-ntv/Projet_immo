# %% [markdown]
# # Changer le CSV et le nom des DF
#
# - output_(n).csv
# cellule 4
#
# - df_data_villes_clean(n)
# cellules: 4, 5, 6
#
# - df_meilleur_agent(n)
# cellules: 7, 8
#
# # Vérifier la shape de df_data_villes_clean(n) et df_meilleur_agent(n)
#
# il doit y avoir le même nombre de lignes

# %%
#pip install selenium selenium-stealth beautifulsoup4 pandas

# %%
from selenium import webdriver
from selenium_stealth import stealth
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import pandas as pd
import re, time, random

# %%
df_data_villes_clean5 = pd.read_csv("pays_de_la_loire5.csv", 
                                    index_col=0,
                                    dtype=str)

# %%
df_data_villes_clean5.head()
# Out:
#       #Code_commune_INSEE           Lib_MA departement Code_postal  \
# 31714               72146        GUECELARD          72       72230
# 31715               72147      LA GUIERCHE          72       72380
# 31716               72148            JAUZE          72       72110
# 31717               72149  JOUE EN CHARNIE          72       72540
# 31718               72150      JOUE L ABBE          72       72380
#
#       Nom_de_la_commune_url                                                url
# 31714             guecelard  https://www.meilleursagents.com/prix-immobilie...
# 31715           la-guierche  https://www.meilleursagents.com/prix-immobilie...
# 31716                 jauze  https://www.meilleursagents.com/prix-immobilie...
# 31717       joue-en-charnie  https://www.meilleursagents.com/prix-immobilie...
# 31718           joue-l-abbe  https://www.meilleursagents.com/prix-immobilie...

# %%
def extract_number(text):
    """Nettoyer le texte et transformer en float"""
    clean_text = text.replace("\u202f", "").replace("\xa0", "").replace("€", "").strip()
    clean_text = clean_text.replace(",", ".")
    return float(clean_text)

# Selenium setup (Chrome auto-managed by Selenium Manager; Chrome must be installed)
options = webdriver.ChromeOptions()
options.add_argument("--lang=fr-FR")
options.add_argument("--disable-blink-features=AutomationControlled")
# Uncomment to persist cookies/session between runs:
# options.add_argument(r"--user-data-dir=C:\Users\Dell\AppData\Local\Google\Chrome\User Data\ScrapeProfile")

driver = webdriver.Chrome(options=options)
stealth(driver,
    languages=["fr-FR", "fr"],
    vendor="Google Inc.",
    platform="Win32",
    webgl_vendor="Intel Inc.",
    renderer="Intel Iris OpenGL Engine",
    fix_hairline=True,
)
driver.set_window_size(1366, 768)

# Lancer le navigateur
driver.get("https://www.meilleursagents.com/prix-immobilier/")

# %%
# Liste pour stocker toutes les données
all_data = []
error_data = []

for index, row in df_data_villes_clean5.iterrows():
    city = row['Lib_MA']+" ("+row['Code_postal']+")"
    try:
        # Human-like pacing
        time.sleep(random.uniform(1.8, 3.6))

        # Trouver la barre de recherche
        search_box = driver.find_element(By.NAME, "q")

        # Simuler une frappe clavier, caractère par caractère
        for y in city:
            search_box.clear()
            search_box.send_keys(y)
            time.sleep(0.05)  # petite pause pour rendre la frappe réaliste

        # Valider avec la touche Entrée
        time.sleep(1)
        search_box.send_keys(Keys.RETURN)
        time.sleep(2)

        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')

        raw_text3 = soup.find_all("ul", class_="prices-summary__price-range")
        data_dict = {}

        #condition pour clear la barre de recherche si il ne trouve pas la ville
        if not raw_text3 :
            driver.refresh()
            time.sleep(3)
        else:
            # Ajouter la ville
            title_text = soup.find("title").get_text().strip()
            ville = title_text.split("Prix immobilier")[1].split("(")[0].strip()
            data_dict["ville"] = ville

            for ul in raw_text3:
                li_items = ul.find_all("li")
                label = li_items[0].get_text().strip().lower()
                main_value = extract_number(li_items[1].get_text())

                # Nettoyer le texte pour récupérer min et max correctement
                range_text = li_items[2].get_text()
                range_text = range_text.replace("\u202f", "").replace("\xa0", "").replace(",", ".")

                # Extraire tous les nombres sous forme de float
                numbers_in_range = [float(n) for n in re.findall(r"[\d\.]+", range_text)]
                if "prix" in label:
                    if "prix_appartement" not in data_dict:
                        data_dict["prix_appartement"] = main_value
                        data_dict["min_appartement"] = numbers_in_range[0]
                        data_dict["max_appartement"] = numbers_in_range[1]
                    else:
                        data_dict["prix_maison"] = main_value
                        data_dict["min_maison"] = numbers_in_range[0]
                        data_dict["max_maison"] = numbers_in_range[1]
                elif "loyer" in label:
                    if "loyer_appartement" not in data_dict:
                        data_dict["loyer_appartement"] = main_value
                        data_dict["loyer_min_appartement"] = numbers_in_range[0]
                        data_dict["loyer_max_appartement"] = numbers_in_range[1]
                    else:
                        data_dict["loyer_maison"] = main_value
                        data_dict["loyer_min_maison"] = numbers_in_range[0]
                        data_dict["loyer_max_maison"] = numbers_in_range[1]

            # Ajouter l'URL pour référence
            data_dict["city"] = city
            all_data.append(data_dict)
            print(f"Datas ajoutées pour la ville : {ville}")

    except Exception as e:
        print(f"Erreur pour la ville {city}: {e}")
        error_data.append({
        "city": city,
        "erreur": str(e)})

    # Pause pour ne pas surcharger le site
    time.sleep(random.uniform(1.8, 3.6))

driver.quit()

# Convertir en DataFrame
# df_scraped = pd.DataFrame(all_data)
# df_scraped.head()
# Out:
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : : le prix du m² partout en France  - Août 2025
# Datas ajoutées pour la ville : Le Gue Lian
# Datas ajoutées pour la ville : Le Gue Lian
# Datas ajoutées pour la ville : Le Gue Lian
# Datas ajoutées pour la ville : Le Gue Lian
# Datas ajoutées pour la ville : Le Gue Lian
# Datas ajoutées pour la ville : Le Gue Lian
# Datas ajoutées pour la ville : Le Gue Lian
# Datas ajoutées pour la ville : Le Gue Lian
# Datas ajoutées pour la ville : Le Gue Lian
# Datas ajoutées pour la ville : Le Gue Lian
# Datas ajoutées pour la ville : Le Gue Lian
# Datas ajoutées pour la ville : Le Gue Lian
# Datas ajoutées pour la ville : Le Gue Lian
# Datas ajoutées pour la ville : Le Gue Lian
# Datas ajoutées pour la ville : Le Gue Lian
# Datas ajoutées pour la ville : Le Gue Lian
# Datas ajoutées pour la ville : Le Gue Lian
# Datas ajoutées pour la ville : Le Gue Lian
# Datas ajoutées pour la ville : Le Gue Lian
# Datas ajoutées pour la ville : Le Gue Lian
# Datas ajoutées pour la ville : Le Gue Lian
# Datas ajoutées pour la ville : Le Gue Lian
# Erreur pour la ville NUILLE LE JALAIS (72370): list index out of range
# Erreur pour la ville OISSEAU LE PETIT (72610): list index out of range
# Erreur pour la ville OIZE (72330): list index out of range
# Erreur pour la ville PANON (72600): list index out of range
# Erreur pour la ville PARCE SUR SARTHE (72300): list index out of range
# Erreur pour la ville PARENNES (72140): list index out of range
# Erreur pour la ville PARIGNE LE POLIN (72330): list index out of range
# Erreur pour la ville PARIGNE L EVEQUE (72250): list index out of range
# Erreur pour la ville NOTRE DAME DU PE (72300): list index out of range
# Erreur pour la ville PERAY (72260): list index out of range
# Erreur pour la ville PEZE LE ROBERT (72140): list index out of range
# Erreur pour la ville PIACE (72170): list index out of range
# Erreur pour la ville PINCE (72300): list index out of range
# Erreur pour la ville PIRMIL (72430): list index out of range
# Erreur pour la ville PIZIEUX (72600): list index out of range
# Erreur pour la ville POILLE SUR VEGRE (72350): list index out of range
# Erreur pour la ville MONTFORT LE GESNOIS (72450): list index out of range
# Erreur pour la ville PONTVALLAIN (72510): list index out of range
# Erreur pour la ville PRECIGNE (72300): list index out of range
# Erreur pour la ville PREVAL (72400): list index out of range
# Erreur pour la ville PREVELLES (72110): list index out of range
# Erreur pour la ville PRUILLE LE CHETIF (72700): list index out of range
# Erreur pour la ville PRUILLE L EGUILLE (72150): list index out of range
# Erreur pour la ville LA QUINTE (72550): list index out of range
# Erreur pour la ville RAHAY (72120): list index out of range
# Erreur pour la ville RENE (72260): list index out of range
# Erreur pour la ville REQUEIL (72510): list index out of range
# Erreur pour la ville ROEZE SUR SARTHE (72210): list index out of range
# Erreur pour la ville ROUESSE FONTAINE (72610): list index out of range
# Erreur pour la ville ROUESSE VASSE (72140): list index out of range
# Erreur pour la ville ROUEZ (72140): list index out of range
# Erreur pour la ville ROUILLON (72700): list index out of range
# Erreur pour la ville ROUPERROUX LE COQUET (72110): list index out of range
# Erreur pour la ville RUAUDIN (72230): list index out of range
# Erreur pour la ville RUILLE EN CHAMPAGNE (72240): list index out of range
# Erreur pour la ville LA CHAPELLE GAUGAIN (72310): list index out of range
# Erreur pour la ville LAVENAY (72310): list index out of range
# Erreur pour la ville PONCE SUR LE LOIR (72340): list index out of range
# Erreur pour la ville RUILLE SUR LOIR (72340): list index out of range
# Erreur pour la ville SABLE SUR SARTHE (72300): list index out of range
# Erreur pour la ville ST AIGNAN (72110): list index out of range
# Erreur pour la ville ST AUBIN DE LOCQUENAY (72130): list index out of range
# Erreur pour la ville ST AUBIN DES COUDRAIS (72400): list index out of range
# Erreur pour la ville ST BIEZ EN BELIN (72220): list index out of range
# Erreur pour la ville ST CALAIS (72120): list index out of range
# Erreur pour la ville ST CALEZ EN SAOSNOIS (72600): list index out of range
# Erreur pour la ville ST CELERIN (72110): list index out of range
# Erreur pour la ville STE CEROTTE (72120): list index out of range
# Erreur pour la ville ST CHRISTOPHE DU JAMBET (72170): list index out of range
# Erreur pour la ville ST CHRISTOPHE EN CHAMPAGNE (72540): list index out of range
# Erreur pour la ville ST CORNEILLE (72460): list index out of range
# Erreur pour la ville ST COSME EN VAIRAIS (72110): list index out of range
# Erreur pour la ville ST DENIS DES COUDRAIS (72110): list index out of range
# Erreur pour la ville ST DENIS D ORQUES (72350): list index out of range
# Erreur pour la ville ST GEORGES DE LA COUEE (72150): list index out of range
# Erreur pour la ville ST GEORGES DU BOIS (72700): list index out of range
# Erreur pour la ville ST GEORGES DU ROSAY (72110): list index out of range
# Erreur pour la ville ST GEORGES LE GAULTIER (72130): list index out of range
# Erreur pour la ville ST GERMAIN D ARCE (72800): list index out of range
# Erreur pour la ville ST GERVAIS DE VIC (72120): list index out of range
# Erreur pour la ville STE JAMME SUR SARTHE (72380): list index out of range
# Erreur pour la ville ST JEAN D ASSE (72380): list index out of range
# Erreur pour la ville ST JEAN DE LA MOTTE (72510): list index out of range
# Erreur pour la ville ST JEAN DES ECHELLES (72320): list index out of range
# Erreur pour la ville ST JEAN DU BOIS (72430): list index out of range
# Erreur pour la ville ST LEONARD DES BOIS (72130): list index out of range
# Erreur pour la ville ST LONGIS (72600): list index out of range
# Erreur pour la ville ST MAIXENT (72320): list index out of range
# Erreur pour la ville ST MARCEAU (72170): list index out of range
# Erreur pour la ville ST MARS D OUTILLE (72220): list index out of range
# Erreur pour la ville ST MARS LA BRIERE (72470): list index out of range
# Erreur pour la ville ST MARTIN DES MONTS (72400): list index out of range
# Erreur pour la ville ST MICHEL DE CHAVAIGNES (72440): list index out of range
# Erreur pour la ville ST OUEN DE MIMBRE (72130): list index out of range
# Erreur pour la ville ST OUEN EN BELIN (72220): list index out of range
# Erreur pour la ville ST OUEN EN CHAMPAGNE (72350): list index out of range
# Erreur pour la ville LE CHEVAIN (72610): list index out of range
# Erreur pour la ville ST PATERNE (72610): list index out of range
# Erreur pour la ville ST PAUL LE GAULTIER (72130): list index out of range
# Erreur pour la ville ST PAVACE (72190): list index out of range
# Erreur pour la ville ST PIERRE DE CHEVILLE (72500): list index out of range
# Erreur pour la ville ST PIERRE DES BOIS (72430): list index out of range
# Erreur pour la ville ST PIERRE DES ORMES (72600): list index out of range
# Erreur pour la ville ST PIERRE DU LOROUER (72150): list index out of range
# Erreur pour la ville ST REMY DE SILLE (72140): list index out of range
# Erreur pour la ville ST REMY DES MONTS (72600): list index out of range
# Erreur pour la ville ST REMY DU VAL (72600): list index out of range
# Erreur pour la ville STE SABINE SUR LONGEVE (72380): list index out of range
# Erreur pour la ville ST SATURNIN (72650): list index out of range
# Erreur pour la ville ST SYMPHORIEN (72240): list index out of range
# Erreur pour la ville ST ULPHACE (72320): list index out of range
# Erreur pour la ville ST VICTEUR (72130): list index out of range
# Erreur pour la ville ST VINCENT DES PRES (72600): list index out of range
# Erreur pour la ville ST VINCENT DU LOROUER (72150): list index out of range
# Erreur pour la ville SAOSNES (72600): list index out of range
# Erreur pour la ville SARCE (72360): list index out of range
# Erreur pour la ville SARGE LES LE MANS (72190): list index out of range
# Erreur pour la ville SAVIGNE L EVEQUE (72460): list index out of range
# Erreur pour la ville SAVIGNE SOUS LE LUDE (72800): list index out of range
# Erreur pour la ville SCEAUX SUR HUISNE (72160): list index out of range
# Erreur pour la ville SEGRIE (72170): list index out of range
# Erreur pour la ville SEMUR EN VALLON (72390): list index out of range
# Erreur pour la ville SILLE LE GUILLAUME (72140): list index out of range
# Erreur pour la ville SILLE LE PHILIPPE (72460): list index out of range
# Erreur pour la ville SOLESMES (72300): list index out of range
# Erreur pour la ville SOUGE LE GANELON (72130): list index out of range
# Erreur pour la ville SOUILLE (72380): list index out of range
# Erreur pour la ville SOULIGNE FLACE (72210): list index out of range
# Erreur pour la ville SOULIGNE SOUS BALLON (72290): list index out of range
# Erreur pour la ville SOULITRE (72370): list index out of range
# Erreur pour la ville SOUVIGNE SUR MEME (72400): list index out of range
# Erreur pour la ville SOUVIGNE SUR SARTHE (72300): list index out of range
# Erreur pour la ville SPAY (72700): list index out of range
# Erreur pour la ville SURFONDS (72370): list index out of range
# Erreur pour la ville LA SUZE SUR SARTHE (72210): list index out of range
# Erreur pour la ville TASSE (72430): list index out of range
# Erreur pour la ville TASSILLE (72540): list index out of range
# Erreur pour la ville TEILLE (72290): list index out of range
# Erreur pour la ville TELOCHE (72220): list index out of range
# Erreur pour la ville TENNIE (72240): list index out of range
# Erreur pour la ville TERREHAULT (72110): list index out of range
# Erreur pour la ville THELIGNY (72320): list index out of range
# Erreur pour la ville THOIGNE (72260): list index out of range
# Erreur pour la ville THOIRE SOUS CONTENSOR (72610): list index out of range
# Erreur pour la ville THOIRE SUR DINAN (72500): list index out of range
# Erreur pour la ville THOREE LES PINS (72800): list index out of range
# Erreur pour la ville THORIGNE SUR DUE (72160): list index out of range
# Erreur pour la ville TORCE EN VALLEE (72110): list index out of range
# Erreur pour la ville TRANGE (72650): list index out of range
# Erreur pour la ville TRESSON (72440): list index out of range
# Erreur pour la ville LE TRONCHET (72170): list index out of range
# Erreur pour la ville ST HILAIRE LE LIERRU (72160): list index out of range
# Erreur pour la ville TUFFE (72160): list index out of range
# Erreur pour la ville VAAS (72500): list index out of range
# Erreur pour la ville VALENNES (72320): list index out of range
# Erreur pour la ville VALLON SUR GEE (72540): list index out of range
# Erreur pour la ville VANCE (72310): list index out of range
# Erreur pour la ville VERNEIL LE CHETIF (72360): list index out of range
# Erreur pour la ville VERNIE (72170): list index out of range
# Erreur pour la ville VEZOT (72600): list index out of range
# Erreur pour la ville VIBRAYE (72320): list index out of range
# Erreur pour la ville VILLAINES LA CARELLE (72600): list index out of range
# Erreur pour la ville VILLAINES LA GONAIS (72400): list index out of range
# Erreur pour la ville VILLAINES SOUS LUCE (72150): list index out of range
# Erreur pour la ville VILLAINES SOUS MALICORNE (72270): list index out of range
# Erreur pour la ville VION (72300): list index out of range
# Erreur pour la ville VIRE EN CHAMPAGNE (72350): list index out of range
# Erreur pour la ville VIVOIN (72170): list index out of range
# Erreur pour la ville VOIVRES LES LE MANS (72210): list index out of range
# Erreur pour la ville ST MARS DE LOCQUENAY (72440): list index out of range
# Erreur pour la ville VOLNAY (72440): list index out of range
# Erreur pour la ville VOUVRAY SUR HUISNE (72160): list index out of range
# Erreur pour la ville YVRE LE POLIN (72330): list index out of range
# Erreur pour la ville YVRE L EVEQUE (72530): list index out of range
# Erreur pour la ville LA FAUTE SUR MER (85460): list index out of range
# Erreur pour la ville L AIGUILLON SUR MER (85460): list index out of range
# Erreur pour la ville L AIGUILLON SUR VIE (85220): list index out of range
# Erreur pour la ville AIZENAY (85190): list index out of range
# Erreur pour la ville ANGLES (85750): list index out of range
# Erreur pour la ville ANTIGNY (85120): list index out of range
# Erreur pour la ville APREMONT (85220): list index out of range
# Erreur pour la ville AUBIGNY (85430): list index out of range
# Erreur pour la ville LES CLOUZEAUX (85430): list index out of range
# Erreur pour la ville AUZAY (85200): list index out of range
# Erreur pour la ville CHAIX (85200): list index out of range
# Erreur pour la ville AVRILLE (85440): list index out of range
# Erreur pour la ville BARBATRE (85630): list index out of range
# Erreur pour la ville LA BARRE DE MONTS (85550): list index out of range
# Datas ajoutées pour la ville : Fromentine
# Datas ajoutées pour la ville : Fromentine
# Datas ajoutées pour la ville : Fromentine
# Datas ajoutées pour la ville : Fromentine
# Datas ajoutées pour la ville : Fromentine
# Datas ajoutées pour la ville : Fromentine
# Datas ajoutées pour la ville : Fromentine
# Datas ajoutées pour la ville : Fromentine
# Datas ajoutées pour la ville : Fromentine
# Datas ajoutées pour la ville : Fromentine
# Datas ajoutées pour la ville : Lesson
# Datas ajoutées pour la ville : Sainte Christine
# Datas ajoutées pour la ville : Sainte Christine
# Datas ajoutées pour la ville : Sainte Christine
# Datas ajoutées pour la ville : Sainte Christine
# Datas ajoutées pour la ville : Sainte Christine
# Datas ajoutées pour la ville : Sainte Christine
# Datas ajoutées pour la ville : Sainte Christine

# %%
driver.quit()

# %%
df_meilleur_agent5 = pd.DataFrame(all_data)
df_error_ma_5 = pd.DataFrame(error_data)

# %%
df_meilleur_agent5.to_csv('ma_11.csv',index=False)
df_error_ma_5.to_csv('error_ma_11.csv',index=False)

# %%
print(df_meilleur_agent5.shape)
print(df_error_ma_5.shape)
# Out:
# (96, 14)
# (168, 2)

# %%
df_error_ma_5.head()
# Out:
#                        city                   erreur
# 0  NUILLE LE JALAIS (72370)  list index out of range
# 1  OISSEAU LE PETIT (72610)  list index out of range
# 2              OIZE (72330)  list index out of range
# 3             PANON (72600)  list index out of range
# 4  PARCE SUR SARTHE (72300)  list index out of range
