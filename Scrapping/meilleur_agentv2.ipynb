# %% [markdown]
# # Bien penser à changer le CSV et le nom des DF !!

# %%
from selenium import webdriver
from selenium_stealth import stealth
from bs4 import BeautifulSoup
import pandas as pd
import re, time, random

# %%
df_data_villes_error_1 = pd.read_csv("villes_error_1.csv", 
                                    delimiter=",",
                                    dtype=str,
                                    index_col=0)

# %%
df_data_villes_error_1.head()
# Out:
#            #Code_commune_INSEE                 Lib_MA departement Code_postal  \
# Unnamed: 0
# 17928                    44009         BASSE GOULAINE          44       44115
# 17939                    44020             BOUGUENAIS          44       44340
# 17940                    44020             LES COUETS          44       44340
# 17957                    44035  LA CHAPELLE SUR ERDRE          44       44240
# 17974                    44052                 DONGES          44       44480
#
#             Nom_de_la_commune_url  \
# Unnamed: 0
# 17928              basse-goulaine
# 17939                  bouguenais
# 17940                  les-couets
# 17957       la-chapelle-sur-erdre
# 17974                      donges
#
#                                                           url
# Unnamed: 0
# 17928       https://www.meilleursagents.com/prix-immobilie...
# 17939       https://www.meilleursagents.com/prix-immobilie...
# 17940       https://www.meilleursagents.com/prix-immobilie...
# 17957       https://www.meilleursagents.com/prix-immobilie...
# 17974       https://www.meilleursagents.com/prix-immobilie...

# %%
def extract_number(text):
    """Nettoyer le texte et transformer en float"""
    clean_text = text.replace("\u202f", "").replace("\xa0", "").replace("€", "").strip()
    clean_text = clean_text.replace(",", ".")
    return float(clean_text)

# Selenium setup (Chrome auto-managed by Selenium Manager; Chrome must be installed)
options = webdriver.ChromeOptions()
options.add_argument("--lang=fr-FR")
options.add_argument("--disable-blink-features=AutomationControlled")
# Uncomment to persist cookies/session between runs:
# options.add_argument(r"--user-data-dir=C:\Users\Dell\AppData\Local\Google\Chrome\User Data\ScrapeProfile")

driver = webdriver.Chrome(options=options)
stealth(driver,
    languages=["fr-FR", "fr"],
    vendor="Google Inc.",
    platform="Win32",
    webgl_vendor="Intel Inc.",
    renderer="Intel Iris OpenGL Engine",
    fix_hairline=True,
)
driver.set_window_size(1366, 768)

# Lancer le navigateur
driver.get("https://www.meilleursagents.com/prix-immobilier/")

# %%
# Liste pour stocker toutes les données
all_data = []
error_data = []

for index, row in df_data_villes_error_1.iterrows():
    url = row['url']
    code_insee = row['#Code_commune_INSEE']
    try:
        # Human-like pacing
        time.sleep(random.uniform(1.8, 3.6))

        driver.get(url)
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')

        
        data_dict = {}
        # 1-Ajouter la ville
        title_text = soup.find("title").get_text().strip()
        ville = title_text.split("Prix immobilier")[1].split("(")[0].strip()
        data_dict["ville"] = ville
        
        #2-ajouter prix achat+loyer au m2 appt et maison
        raw_text3 = soup.find_all("ul", class_="prices-summary__price-range")
        for ul in raw_text3:
            li_items = ul.find_all("li")
            label = li_items[0].get_text().strip().lower()
            main_value = extract_number(li_items[1].get_text())
            # Nettoyer le texte pour récupérer min et max correctement
            range_text = li_items[2].get_text()
            range_text = range_text.replace("\u202f", "").replace("\xa0", "").replace(",", ".")
            # Extraire tous les nombres sous forme de float
            numbers_in_range = [float(n) for n in re.findall(r"[\d\.]+", range_text)]
            if "prix" in label:
                if "prix_appartement" not in data_dict:
                    data_dict["prix_appartement"] = main_value
                    data_dict["min_appartement"] = numbers_in_range[0]
                    data_dict["max_appartement"] = numbers_in_range[1]
                else:
                    data_dict["prix_maison"] = main_value
                    data_dict["min_maison"] = numbers_in_range[0]
                    data_dict["max_maison"] = numbers_in_range[1]
            elif "loyer" in label:
                if "loyer_appartement" not in data_dict:
                    data_dict["loyer_appartement"] = main_value
                    data_dict["loyer_min_appartement"] = numbers_in_range[0]
                    data_dict["loyer_max_appartement"] = numbers_in_range[1]
                else:
                    data_dict["loyer_maison"] = main_value
                    data_dict["loyer_min_maison"] = numbers_in_range[0]
                    data_dict["loyer_max_maison"] = numbers_in_range[1]
        
        #3-Ajouter l'URL pour référence
        data_dict["url"] = url
        data_dict['Code_insee'] = code_insee
        all_data.append(data_dict)
        print(f"Datas ajoutées pour la ville : {ville}")
        
    except Exception as erreur:
        print(f"Erreur pour l'URL {url}: {erreur}")
        error_data.append({
        "url": url,
        "erreur": str(erreur)})
        
    # Pause pour ne pas surcharger le site
    time.sleep(random.uniform(2.3, 3.6))

driver.quit()
# Out:
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/basse-goulaine-44115/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/bouguenais-44340/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/les-couets-44340/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/la-chapelle-sur-erdre-44240/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/donges-44480/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/fay-de-bretagne-44130/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/grandchamp-des-fontaines-44119/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/heric-44810/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/basse-indre-44610/: list index out of range
# Datas ajoutées pour la ville : Marsac-sur-Don
# Datas ajoutées pour la ville : La Montagne
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/nantes-44100/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/nantes-44200/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/nantes-44300/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/nort-sur-erdre-44390/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/orvault-44700/: list index out of range
# Datas ajoutées pour la ville : Pont-Saint-Martin
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/pornic-44210/: list index out of range
# Datas ajoutées pour la ville : Port-Saint-Père
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/le-pouliguen-44510/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/pont-rousseau-44400/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/pont-james-44310/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/saint-herblain-44800/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/freigne-44540/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/saint-michel-chef-chef-44730/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/saint-marc-sur-mer-44600/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/saint-sebastien-sur-loire-44230/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/sautron-44880/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/treillieres-44119/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/vallet-44330/: list index out of range
# Datas ajoutées pour la ville : Loireauxence
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/vertou-44120/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/angers-49100/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/gohier-49320/: list index out of range
# Datas ajoutées pour la ville : Charcé-Saint-Ellier-sur-Aubance
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/chalonnes-sur-loire-49290/: list index out of range
# Datas ajoutées pour la ville : La Chapelle-Saint-Laud
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/chemille-melay-49120/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/joue-etiau-49670/: list index out of range
# Datas ajoutées pour la ville : Le Puy Saint Bonnet
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/montreuil-juigne-49460/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/juigne-bene-49460/: list index out of range
# Datas ajoutées pour la ville : Mauges-sur-Loire
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/chenehutte-les-tuffeaux-49350/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/saint-barthelemy-d-anjou-49124/: list index out of range
# Datas ajoutées pour la ville : Saint Hilaire Saint Florent
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/trelaze-49800/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/le-voide-49310/: list index out of range
# Datas ajoutées pour la ville : Le Genest-Saint-Isle
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/l-huisserie-53970/: list index out of range
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/laval-53000/: list index out of range
# Datas ajoutées pour la ville : Quelaines-Saint-Gault
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/ravigny-53370/: list index out of range
# Datas ajoutées pour la ville : La Chapelle-Saint-Aubin
# Datas ajoutées pour la ville : La Chapelle-Saint-Fray
# Datas ajoutées pour la ville : La Chapelle-Saint-Rémy
# Datas ajoutées pour la ville : La Fontaine-Saint-Martin
# Datas ajoutées pour la ville : Longnes
# Datas ajoutées pour la ville : Louailles
# Datas ajoutées pour la ville : Loué
# Datas ajoutées pour la ville : Louplande
# Datas ajoutées pour la ville : Louvigny
# Datas ajoutées pour la ville : Louzes
# Datas ajoutées pour la ville : Le Luart
# Datas ajoutées pour la ville : Luceau
# Datas ajoutées pour la ville : Lucé-sous-Ballon
# Datas ajoutées pour la ville : Luché-Pringé
# Datas ajoutées pour la ville : Le Lude
# Datas ajoutées pour la ville : Dissé-sous-le-Lude
# Datas ajoutées pour la ville : Maigné
# Datas ajoutées pour la ville : Maisoncelles
# Datas ajoutées pour la ville : Malicorne-sur-Sarthe
# Datas ajoutées pour la ville : Mamers
# Datas ajoutées pour la ville : Le Mans
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/le-mans-72100/: list index out of range
# Datas ajoutées pour la ville : Mansigné
# Datas ajoutées pour la ville : Marçon
# Datas ajoutées pour la ville : Mareil-en-Champagne
# Datas ajoutées pour la ville : Mareil-sur-Loir
# Datas ajoutées pour la ville : Maresché
# Datas ajoutées pour la ville : Marigné-Laillé
# Datas ajoutées pour la ville : Marollette
# Datas ajoutées pour la ville : Marolles-les-Braults
# Datas ajoutées pour la ville : Dissé-sous-Ballon
# Datas ajoutées pour la ville : Marolles-lès-Saint-Calais
# Datas ajoutées pour la ville : Mayet
# Datas ajoutées pour la ville : Les Mées
# Datas ajoutées pour la ville : Melleray
# Datas ajoutées pour la ville : Meurcé
# Datas ajoutées pour la ville : Mézeray
# Datas ajoutées pour la ville : Mézières-sur-Ponthouin
# Datas ajoutées pour la ville : Mézières-sous-Lavardin
# Datas ajoutées pour la ville : La Milesse
# Datas ajoutées pour la ville : Moitron-sur-Sarthe
# Datas ajoutées pour la ville : Le Gue Lian
# Datas ajoutées pour la ville : Moncé-en-Belin
# Datas ajoutées pour la ville : Moncé-en-Saosnois
# Datas ajoutées pour la ville : Monhoudou
# Datas ajoutées pour la ville : Montaillé
# Datas ajoutées pour la ville : Montbizot
# Datas ajoutées pour la ville : Montmirail
# Datas ajoutées pour la ville : Montreuil-le-Chétif
# Datas ajoutées pour la ville : Montreuil-le-Henri
# Datas ajoutées pour la ville : Mont-Saint-Jean
# Datas ajoutées pour la ville : Moulins-le-Carbonnel
# Datas ajoutées pour la ville : Mulsanne
# Datas ajoutées pour la ville : Nauvay
# Datas ajoutées pour la ville : Neufchâtel-en-Saosnois
# Datas ajoutées pour la ville : Neuvillalais
# Datas ajoutées pour la ville : Neuville-sur-Sarthe
# Datas ajoutées pour la ville : Neuvillette-en-Charnie
# Datas ajoutées pour la ville : Bernay-en-Champagne
# Datas ajoutées pour la ville : Neuvy-en-Champagne
# Datas ajoutées pour la ville : Nogent-le-Bernard
# Datas ajoutées pour la ville : Nogent-sur-Loir
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/nouans-72260/: 'NoneType' object has no attribute 'get_text'
# Datas ajoutées pour la ville : Noyen-sur-Sarthe
# Datas ajoutées pour la ville : Nuillé-le-Jalais
# Datas ajoutées pour la ville : Oisseau-le-Petit
# Datas ajoutées pour la ville : Oizé
# Datas ajoutées pour la ville : Panon
# Datas ajoutées pour la ville : Parcé-sur-Sarthe
# Datas ajoutées pour la ville : Parennes
# Datas ajoutées pour la ville : Parigné-le-Pôlin
# Datas ajoutées pour la ville : Parigné-l'Évêque
# Datas ajoutées pour la ville : Notre-Dame-du-Pé
# Datas ajoutées pour la ville : Peray
# Datas ajoutées pour la ville : Pezé-le-Robert
# Datas ajoutées pour la ville : Piacé
# Datas ajoutées pour la ville : Pincé
# Datas ajoutées pour la ville : Pirmil
# Datas ajoutées pour la ville : Pizieux
# Datas ajoutées pour la ville : Poillé-sur-Vègre
# Datas ajoutées pour la ville : Montfort-le-Gesnois
# Datas ajoutées pour la ville : Pontvallain
# Datas ajoutées pour la ville : Précigné
# Datas ajoutées pour la ville : Préval
# Datas ajoutées pour la ville : Prévelles
# Datas ajoutées pour la ville : Pruillé-le-Chétif
# Datas ajoutées pour la ville : Pruillé-l'Éguillé
# Datas ajoutées pour la ville : La Quinte
# Datas ajoutées pour la ville : Rahay
# Datas ajoutées pour la ville : René
# Datas ajoutées pour la ville : Requeil
# Datas ajoutées pour la ville : Roézé-sur-Sarthe
# Datas ajoutées pour la ville : Rouessé-Fontaine
# Datas ajoutées pour la ville : Rouessé-Vassé
# Datas ajoutées pour la ville : Rouez
# Datas ajoutées pour la ville : Rouillon
# Datas ajoutées pour la ville : Rouperroux-le-Coquet
# Datas ajoutées pour la ville : Ruaudin
# Datas ajoutées pour la ville : Ruillé-en-Champagne
# Datas ajoutées pour la ville : La Chapelle-Gaugain
# Datas ajoutées pour la ville : Lavenay
# Datas ajoutées pour la ville : Poncé-sur-le-Loir
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/pont-de-braye-72340/: list index out of range
# Datas ajoutées pour la ville : Ruillé-sur-Loir
# Datas ajoutées pour la ville : Sablé-sur-Sarthe
# Datas ajoutées pour la ville : Saint-Aignan
# Datas ajoutées pour la ville : Saint-Aubin-de-Locquenay
# Datas ajoutées pour la ville : Saint-Aubin-des-Coudrais
# Datas ajoutées pour la ville : Saint-Biez-en-Belin
# Datas ajoutées pour la ville : Saint-Calais
# Datas ajoutées pour la ville : Saint-Calez-en-Saosnois
# Datas ajoutées pour la ville : Saint-Célerin
# Datas ajoutées pour la ville : Sainte-Cérotte
# Datas ajoutées pour la ville : Saint-Christophe-du-Jambet
# Datas ajoutées pour la ville : Saint-Christophe-en-Champagne
# Datas ajoutées pour la ville : Saint-Corneille
# Datas ajoutées pour la ville : Saint-Cosme-en-Vairais
# Datas ajoutées pour la ville : Saint-Denis-des-Coudrais
# Datas ajoutées pour la ville : Saint-Denis-d'Orques
# Datas ajoutées pour la ville : Saint-Georges-de-la-Couée
# Datas ajoutées pour la ville : Saint-Georges-du-Bois
# Datas ajoutées pour la ville : Saint-Georges-du-Rosay
# Datas ajoutées pour la ville : Saint-Georges-le-Gaultier
# Datas ajoutées pour la ville : Saint-Germain-d'Arcé
# Datas ajoutées pour la ville : Saint-Gervais-de-Vic
# Datas ajoutées pour la ville : Sainte-Jamme-sur-Sarthe
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/antoigne-72380/: list index out of range
# Datas ajoutées pour la ville : Saint-Jean-d'Assé
# Datas ajoutées pour la ville : Saint-Jean-de-la-Motte
# Datas ajoutées pour la ville : Saint-Jean-des-Échelles
# Datas ajoutées pour la ville : Saint-Jean-du-Bois
# Datas ajoutées pour la ville : Saint-Léonard-des-Bois
# Datas ajoutées pour la ville : Saint-Longis
# Datas ajoutées pour la ville : Saint-Maixent
# Datas ajoutées pour la ville : Saint-Marceau
# Datas ajoutées pour la ville : Saint-Mars-d'Outillé
# Datas ajoutées pour la ville : Saint-Mars-la-Brière
# Datas ajoutées pour la ville : Saint-Martin-des-Monts
# Datas ajoutées pour la ville : Saint-Michel-de-Chavaignes
# Datas ajoutées pour la ville : Saint-Ouen-de-Mimbré
# Datas ajoutées pour la ville : Saint-Ouen-en-Belin
# Datas ajoutées pour la ville : Saint-Ouen-en-Champagne
# Datas ajoutées pour la ville : Le Chevain
# Datas ajoutées pour la ville : Saint-Paterne
# Datas ajoutées pour la ville : Saint-Paul-le-Gaultier
# Datas ajoutées pour la ville : Saint-Pavace
# Datas ajoutées pour la ville : Saint-Pierre-de-Chevillé
# Datas ajoutées pour la ville : Saint-Pierre-des-Bois
# Datas ajoutées pour la ville : Saint-Pierre-des-Ormes
# Datas ajoutées pour la ville : Saint-Pierre-du-Lorouër
# Datas ajoutées pour la ville : Saint-Rémy-de-Sillé
# Datas ajoutées pour la ville : Saint-Rémy-des-Monts
# Datas ajoutées pour la ville : Saint-Rémy-du-Val
# Datas ajoutées pour la ville : Sainte-Sabine-sur-Longève
# Datas ajoutées pour la ville : Saint-Saturnin
# Datas ajoutées pour la ville : Saint-Symphorien
# Datas ajoutées pour la ville : Saint-Ulphace
# Datas ajoutées pour la ville : Saint-Victeur
# Datas ajoutées pour la ville : Saint-Vincent-des-Prés
# Datas ajoutées pour la ville : Saint-Vincent-du-Lorouër
# Datas ajoutées pour la ville : Saosnes
# Datas ajoutées pour la ville : Sarcé
# Datas ajoutées pour la ville : Sargé-lès-le-Mans
# Datas ajoutées pour la ville : Savigné-l'Évêque
# Datas ajoutées pour la ville : Savigné-sous-le-Lude
# Datas ajoutées pour la ville : Sceaux-sur-Huisne
# Datas ajoutées pour la ville : Ségrie
# Datas ajoutées pour la ville : Semur-en-Vallon
# Datas ajoutées pour la ville : Sillé-le-Guillaume
# Datas ajoutées pour la ville : Sillé-le-Philippe
# Datas ajoutées pour la ville : Solesmes
# Datas ajoutées pour la ville : Sougé-le-Ganelon
# Datas ajoutées pour la ville : Souillé
# Datas ajoutées pour la ville : Souligné-Flacé
# Datas ajoutées pour la ville : Souligné-sous-Ballon
# Datas ajoutées pour la ville : Soulitré
# Datas ajoutées pour la ville : Souvigné-sur-Même
# Datas ajoutées pour la ville : Souvigné-sur-Sarthe
# Datas ajoutées pour la ville : Spay
# Datas ajoutées pour la ville : Surfonds
# Datas ajoutées pour la ville : La Suze-sur-Sarthe
# Datas ajoutées pour la ville : Tassé
# Datas ajoutées pour la ville : Tassillé
# Datas ajoutées pour la ville : Teillé
# Datas ajoutées pour la ville : Teloché
# Datas ajoutées pour la ville : Tennie
# Datas ajoutées pour la ville : Terrehault
# Datas ajoutées pour la ville : Théligny
# Datas ajoutées pour la ville : Thoigné
# Datas ajoutées pour la ville : Thoiré-sous-Contensor
# Datas ajoutées pour la ville : Thoiré-sur-Dinan
# Datas ajoutées pour la ville : Thorée-les-Pins
# Datas ajoutées pour la ville : Thorigné-sur-Dué
# Datas ajoutées pour la ville : Torcé-en-Vallée
# Datas ajoutées pour la ville : Trangé
# Datas ajoutées pour la ville : Tresson
# Datas ajoutées pour la ville : Le Tronchet
# Datas ajoutées pour la ville : Tuffé Val de la Chéronne
# Datas ajoutées pour la ville : Tuffé Val de la Chéronne
# Datas ajoutées pour la ville : Vaas
# Datas ajoutées pour la ville : Valennes
# Datas ajoutées pour la ville : Vallon-sur-Gée
# Datas ajoutées pour la ville : Vancé
# Datas ajoutées pour la ville : Verneil-le-Chétif
# Datas ajoutées pour la ville : Vernie
# Datas ajoutées pour la ville : Vezot
# Datas ajoutées pour la ville : Vibraye
# Datas ajoutées pour la ville : Villaines-la-Carelle
# Datas ajoutées pour la ville : Villaines-la-Gonais
# Datas ajoutées pour la ville : Villaines-sous-Lucé
# Datas ajoutées pour la ville : Villaines-sous-Malicorne
# Datas ajoutées pour la ville : Vion
# Datas ajoutées pour la ville : Viré-en-Champagne
# Datas ajoutées pour la ville : Vivoin
# Datas ajoutées pour la ville : Voivres-lès-le-Mans
# Datas ajoutées pour la ville : Saint-Mars-de-Locquenay
# Datas ajoutées pour la ville : Volnay
# Datas ajoutées pour la ville : Vouvray-sur-Huisne
# Datas ajoutées pour la ville : Yvré-le-Pôlin
# Datas ajoutées pour la ville : Yvré-l'Évêque
# Datas ajoutées pour la ville : La Faute-sur-Mer
# Datas ajoutées pour la ville : L'Aiguillon-sur-Mer
# Datas ajoutées pour la ville : L'Aiguillon-sur-Vie
# Datas ajoutées pour la ville : Aizenay
# Datas ajoutées pour la ville : Angles
# Datas ajoutées pour la ville : Antigny
# Datas ajoutées pour la ville : Apremont
# Datas ajoutées pour la ville : Aubigny-Les Clouzeaux
# Datas ajoutées pour la ville : Aubigny-Les Clouzeaux
# Datas ajoutées pour la ville : Auzay
# Datas ajoutées pour la ville : Chaix
# Datas ajoutées pour la ville : Avrillé
# Datas ajoutées pour la ville : Barbâtre
# Datas ajoutées pour la ville : La Barre-de-Monts
# Datas ajoutées pour la ville : Fromentine
# Datas ajoutées pour la ville : Bazoges-en-Paillers
# Datas ajoutées pour la ville : Bazoges-en-Pareds
# Datas ajoutées pour la ville : Beaufou
# Datas ajoutées pour la ville : Beaulieu-sous-la-Roche
# Datas ajoutées pour la ville : Beaurepaire
# Datas ajoutées pour la ville : Beauvoir-sur-Mer
# Datas ajoutées pour la ville : Bellevigny
# Datas ajoutées pour la ville : Bellevigny
# Datas ajoutées pour la ville : Benet
# Datas ajoutées pour la ville : Lesson
# Datas ajoutées pour la ville : Sainte Christine
# Datas ajoutées pour la ville : Le Bernard
# Datas ajoutées pour la ville : Bessay
# Datas ajoutées pour la ville : Bois-de-Céné
# Datas ajoutées pour la ville : La Boissière-de-Montaigu
# Datas ajoutées pour la ville : La Boissière-des-Landes
# Datas ajoutées pour la ville : Bouillé-Courdault
# Datas ajoutées pour la ville : Bouin
# Datas ajoutées pour la ville : Le Boupère
# Datas ajoutées pour la ville : Bourneau
# Datas ajoutées pour la ville : Bournezeau
# Datas ajoutées pour la ville : Saint Vincent Puymaufrais
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/bretignolles-sur-mer-85470/: list index out of range
# Datas ajoutées pour la ville : La Bretonnière-la-Claye
# Datas ajoutées pour la ville : La Claye
# Datas ajoutées pour la ville : Les Brouzils
# Datas ajoutées pour la ville : La Bruffière
# Datas ajoutées pour la ville : La Caillère-Saint-Hilaire
# Datas ajoutées pour la ville : Saint Hilaire du Bois
# Datas ajoutées pour la ville : Chaillé-les-Marais
# Datas ajoutées pour la ville : Aisne
# Datas ajoutées pour la ville : Sableau
# Datas ajoutées pour la ville : La Chaize-Giraud
# Datas ajoutées pour la ville : La Chaize-le-Vicomte
# Datas ajoutées pour la ville : La Limouziniere
# Datas ajoutées pour la ville : Challans
# Datas ajoutées pour la ville : Champagné-les-Marais
# Datas ajoutées pour la ville : Le Champ-Saint-Père
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/chantonnay-85110/: list index out of range
# Datas ajoutées pour la ville : Saint Philbert du Pont Charrault
# Datas ajoutées pour la ville : La Chapelle-Hermier
# Datas ajoutées pour la ville : La Chapelle-Palluau
# Datas ajoutées pour la ville : La Chapelle-Thémer
# Datas ajoutées pour la ville : Chasnais
# Datas ajoutées pour la ville : La Châtaigneraie
# Datas ajoutées pour la ville : Château-Guibert
# Datas ajoutées pour la ville : Châteauneuf
# Datas ajoutées pour la ville : Chauché
# Datas ajoutées pour la ville : Chavagnes-en-Paillers
# Datas ajoutées pour la ville : Chavagnes-les-Redoux
# Datas ajoutées pour la ville : Cheffois
# Datas ajoutées pour la ville : Coëx
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/commequiers-85220/: list index out of range
# Datas ajoutées pour la ville : La Copechagnière
# Datas ajoutées pour la ville : Corpe
# Datas ajoutées pour la ville : La Couture
# Datas ajoutées pour la ville : Cugand
# Datas ajoutées pour la ville : La Bernardière
# Datas ajoutées pour la ville : Curzon
# Datas ajoutées pour la ville : Damvix
# Datas ajoutées pour la ville : Doix lès Fontaines
# Datas ajoutées pour la ville : Doix lès Fontaines
# Datas ajoutées pour la ville : Dompierre-sur-Yon
# Datas ajoutées pour la ville : Les Epesses
# Datas ajoutées pour la ville : L'Épine
# Datas ajoutées pour la ville : Essarts en Bocage
# Datas ajoutées pour la ville : Essarts en Bocage
# Datas ajoutées pour la ville : Falleron
# Datas ajoutées pour la ville : Faymoreau
# Datas ajoutées pour la ville : Le Fenouiller
# Datas ajoutées pour la ville : La Ferrière
# Datas ajoutées pour la ville : Sèvremont
# Datas ajoutées pour la ville : Sèvremont
# Datas ajoutées pour la ville : Sèvremont
# Datas ajoutées pour la ville : Sèvremont
# Datas ajoutées pour la ville : Fontenay-le-Comte
# Datas ajoutées pour la ville : Saint Medard des Pres
# Datas ajoutées pour la ville : Fougeré
# Datas ajoutées pour la ville : Foussais-Payré
# Datas ajoutées pour la ville : Froidfond
# Datas ajoutées pour la ville : La Garnache
# Datas ajoutées pour la ville : La Gaubretière
# Datas ajoutées pour la ville : La Génétouze
# Datas ajoutées pour la ville : Le Girouard
# Datas ajoutées pour la ville : Givrand
# Datas ajoutées pour la ville : Le Givre
# Datas ajoutées pour la ville : Grand'Landes
# Datas ajoutées pour la ville : Grosbreuil
# Datas ajoutées pour la ville : Grues
# Datas ajoutées pour la ville : Le Gué-de-Velluire
# Datas ajoutées pour la ville : La Guérinière
# Datas ajoutées pour la ville : L'Herbergement
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/les-herbiers-85500/: list index out of range
# Datas ajoutées pour la ville : L'Hermenault
# Datas ajoutées pour la ville : L'Île-d'Elle
# Datas ajoutées pour la ville : L'Île-d'Olonne
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/l-ile-d-yeu-85350/: list index out of range
# Datas ajoutées pour la ville : Port Joinville
# Datas ajoutées pour la ville : Jard-sur-Mer
# Datas ajoutées pour la ville : La Jaudonnière
# Datas ajoutées pour la ville : La Jonchère
# Datas ajoutées pour la ville : Lairoux
# Datas ajoutées pour la ville : Landeronde
# Datas ajoutées pour la ville : Les Landes-Genusson
# Datas ajoutées pour la ville : Landevieille
# Datas ajoutées pour la ville : Le Langon
# Datas ajoutées pour la ville : Liez
# Datas ajoutées pour la ville : Loge-Fougereuse
# Datas ajoutées pour la ville : Longèves
# Datas ajoutées pour la ville : Longeville-sur-Mer
# Datas ajoutées pour la ville : Luçon
# Datas ajoutées pour la ville : Les Lucs-sur-Boulogne
# Datas ajoutées pour la ville : Maché
# Datas ajoutées pour la ville : Les Magnils-Reigniers
# Datas ajoutées pour la ville : Maillé
# Datas ajoutées pour la ville : Maillezais
# Datas ajoutées pour la ville : Mallièvre
# Datas ajoutées pour la ville : Mareuil-sur-Lay-Dissais
# Datas ajoutées pour la ville : Dissais
# Datas ajoutées pour la ville : Marillet
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/marsais-ste-radegonde-85570/: list index out of range
# Datas ajoutées pour la ville : Martinet
# Datas ajoutées pour la ville : Le Mazeau
# Datas ajoutées pour la ville : La Meilleraie-Tillay
# Datas ajoutées pour la ville : Menomblet
# Datas ajoutées pour la ville : La Merlatière
# Datas ajoutées pour la ville : Mervent
# Datas ajoutées pour la ville : Mesnard-la-Barotière
# Datas ajoutées pour la ville : Monsireigne
# Datas ajoutées pour la ville : Boufféré
# Datas ajoutées pour la ville : La Guyonnière
# Datas ajoutées pour la ville : Montaigu
# Datas ajoutées pour la ville : Saint-Georges-de-Montaigu
# Datas ajoutées pour la ville : Saint-Hilaire-de-Loulay
# Datas ajoutées pour la ville : Montournais
# Datas ajoutées pour la ville : Montreuil
# Datas ajoutées pour la ville : Moreilles
# Datas ajoutées pour la ville : Mortagne-sur-Sèvre
# Datas ajoutées pour la ville : La Chapelle-Achard
# Datas ajoutées pour la ville : La Mothe-Achard
# Datas ajoutées pour la ville : Mouchamps
# Datas ajoutées pour la ville : Mouilleron-Saint-Germain
# Datas ajoutées pour la ville : Mouilleron-Saint-Germain
# Datas ajoutées pour la ville : Mouilleron-le-Captif
# Datas ajoutées pour la ville : Moutiers-les-Mauxfaits
# Datas ajoutées pour la ville : Moutiers-sur-le-Lay
# Datas ajoutées pour la ville : Mouzeuil-Saint-Martin
# Datas ajoutées pour la ville : Nalliers
# Datas ajoutées pour la ville : Nesmy
# Datas ajoutées pour la ville : Nieul-le-Dolent
# Datas ajoutées pour la ville : Nieul-sur-l'Autise
# Datas ajoutées pour la ville : Oulmes
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/noirmoutier-en-l-ile-85330/: list index out of range
# Datas ajoutées pour la ville : Notre-Dame-de-Monts
# Datas ajoutées pour la ville : Essarts en Bocage
# Datas ajoutées pour la ville : L'Orbrie
# Datas ajoutées pour la ville : Palluau
# Datas ajoutées pour la ville : Péault
# Datas ajoutées pour la ville : Le Perrier
# Datas ajoutées pour la ville : Petosse
# Datas ajoutées pour la ville : Les Pineaux
# Datas ajoutées pour la ville : Pissotte
# Datas ajoutées pour la ville : Le Poiré-sur-Velluire
# Datas ajoutées pour la ville : Velluire
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/le-poire-sur-vie-85170/: list index out of range
# Datas ajoutées pour la ville : Poiroux
# Datas ajoutées pour la ville : Pouillé
# Datas ajoutées pour la ville : Pouzauges
# Datas ajoutées pour la ville : Puy-de-Serre
# Datas ajoutées pour la ville : Puyravault
# Datas ajoutées pour la ville : La Rabatelière
# Datas ajoutées pour la ville : Réaumur
# Datas ajoutées pour la ville : La Réorthe
# Datas ajoutées pour la ville : Notre-Dame-de-Riez
# Datas ajoutées pour la ville : Rocheservière
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/la-roche-sur-yon-85000/: list index out of range
# Datas ajoutées pour la ville : Rochetrejoux
# Datas ajoutées pour la ville : Rosnay
# Datas ajoutées pour la ville : Les Sables-d'Olonne
# Datas ajoutées pour la ville : Château-d'Olonne
# Datas ajoutées pour la ville : Olonne-sur-Mer
# Datas ajoutées pour la ville : Saint-André-Goule-d'Oie
# Datas ajoutées pour la ville : Montréverd
# Datas ajoutées pour la ville : Montréverd
# Datas ajoutées pour la ville : Montréverd
# Datas ajoutées pour la ville : Saint-Aubin-des-Ormeaux
# Datas ajoutées pour la ville : Saint-Aubin-la-Plaine
# Datas ajoutées pour la ville : Saint-Avaugourd-des-Landes
# Datas ajoutées pour la ville : Saint-Benoist-sur-Mer
# Datas ajoutées pour la ville : Sainte-Cécile
# Datas ajoutées pour la ville : Saint-Christophe-du-Ligneron
# Datas ajoutées pour la ville : Saint-Cyr-des-Gâts
# Datas ajoutées pour la ville : Saint-Cyr-en-Talmondais
# Datas ajoutées pour la ville : Saint-Denis-du-Payré
# Datas ajoutées pour la ville : Saint-Denis-la-Chevasse
# Datas ajoutées pour la ville : Saint-Étienne-de-Brillouet
# Datas ajoutées pour la ville : Saint-Étienne-du-Bois
# Datas ajoutées pour la ville : Sainte-Flaive-des-Loups
# Datas ajoutées pour la ville : Essarts en Bocage
# Datas ajoutées pour la ville : Rives de l'Yon
# Datas ajoutées pour la ville : Rives de l'Yon
# Datas ajoutées pour la ville : Sainte-Foy
# Datas ajoutées pour la ville : Saint-Fulgent
# Datas ajoutées pour la ville : Sainte-Gemme-la-Plaine
# Datas ajoutées pour la ville : Saint-Georges-de-Pointindoux
# Datas ajoutées pour la ville : Saint-Germain-de-Prinçay
# Datas ajoutées pour la ville : Saint-Gervais
# Datas ajoutées pour la ville : Saint-Gilles-Croix-de-Vie
# Datas ajoutées pour la ville : Sainte-Hermine
# Datas ajoutées pour la ville : Saint-Jean-de-Beugné
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/saint-hilaire-de-riez-85270/: list index out of range
# Datas ajoutées pour la ville : Sion sur l'Ocean
# Datas ajoutées pour la ville : Saint-Hilaire-des-Loges
# Datas ajoutées pour la ville : Saint-Hilaire-de-Voust
# Datas ajoutées pour la ville : Saint-Hilaire-la-Forêt
# Datas ajoutées pour la ville : Saint-Hilaire-le-Vouhis
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/saint-jean-de-monts-85160/: list index out of range
# Datas ajoutées pour la ville : Saint-Juire-Champgillon
# Datas ajoutées pour la ville : Saint-Julien-des-Landes
# Datas ajoutées pour la ville : Saint-Laurent-de-la-Salle
# Datas ajoutées pour la ville : Saint-Laurent-sur-Sèvre
# Datas ajoutées pour la ville : Saint-Maixent-sur-Vie
# Datas ajoutées pour la ville : Saint-Malô-du-Bois
# Datas ajoutées pour la ville : Saint-Mars-la-Réorthe
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/brem-sur-mer-85470/: list index out of range
# Datas ajoutées pour la ville : Saint Nicolas de Brem
# Datas ajoutées pour la ville : Saint-Martin-de-Fraigneau
# Datas ajoutées pour la ville : Saint-Martin-des-Fontaines
# Datas ajoutées pour la ville : Saint-Martin-des-Noyers
# Datas ajoutées pour la ville : Saint-Martin-des-Tilleuls
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/saint-martin-lars-en-ste-hermine-85210/: list index out of range
# Datas ajoutées pour la ville : Saint-Mathurin
# Datas ajoutées pour la ville : Saint-Maurice-des-Noues
# Datas ajoutées pour la ville : Saint-Maurice-le-Girard
# Datas ajoutées pour la ville : Saint-Mesmin
# Datas ajoutées pour la ville : Saint-Michel-en-l'Herm
# Datas ajoutées pour la ville : Saint-Michel-le-Cloucq
# Datas ajoutées pour la ville : Saint-Paul-en-Pareds
# Datas ajoutées pour la ville : Saint-Paul-Mont-Penit
# Datas ajoutées pour la ville : Sainte-Pexine
# Datas ajoutées pour la ville : Saint-Philbert-de-Bouaine
# Datas ajoutées pour la ville : Saint-Pierre-du-Chemin
# Datas ajoutées pour la ville : Saint-Pierre-le-Vieux
# Datas ajoutées pour la ville : Saint-Prouant
# Datas ajoutées pour la ville : Sainte-Radégonde-des-Noyers
# Datas ajoutées pour la ville : Saint-Révérend
# Datas ajoutées pour la ville : Saint-Sigismond
# Datas ajoutées pour la ville : Saint-Urbain
# Datas ajoutées pour la ville : Saint-Valérien
# Datas ajoutées pour la ville : Saint-Vincent-Sterlanges
# Datas ajoutées pour la ville : Saint-Vincent-sur-Graon
# Datas ajoutées pour la ville : Saint Sornin
# Datas ajoutées pour la ville : Saint-Vincent-sur-Jard
# Datas ajoutées pour la ville : Sallertaine
# Datas ajoutées pour la ville : Sérigné
# Datas ajoutées pour la ville : Sigournais
# Datas ajoutées pour la ville : Soullans
# Datas ajoutées pour la ville : Le Tablier
# Datas ajoutées pour la ville : La Taillée
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/tallud-ste-gemme-85390/: list index out of range
# Datas ajoutées pour la ville : Talmont-Saint-Hilaire
# Datas ajoutées pour la ville : Saint Hilaire de Talmont
# Datas ajoutées pour la ville : Breuil-Barret
# Datas ajoutées pour la ville : La Chapelle-aux-Lys
# Erreur pour l'URL https://www.meilleursagents.com/prix-immobilier/la-tardiere-85120/: list index out of range
# Datas ajoutées pour la ville : Thiré
# Datas ajoutées pour la ville : Thorigny
# Datas ajoutées pour la ville : Cezais
# Datas ajoutées pour la ville : Saint-Sulpice-en-Pareds
# Datas ajoutées pour la ville : Thouarsais-Bouildroux
# Datas ajoutées pour la ville : Tiffauges
# Datas ajoutées pour la ville : La Tranche-sur-Mer
# Datas ajoutées pour la ville : Treize-Septiers
# Datas ajoutées pour la ville : Treize-Vents
# Datas ajoutées pour la ville : Triaize
# Datas ajoutées pour la ville : Vairé
# Datas ajoutées pour la ville : Venansault
# Datas ajoutées pour la ville : Vendrennes
# Datas ajoutées pour la ville : La Verrie
# Datas ajoutées pour la ville : Chambretaud
# Datas ajoutées pour la ville : Vix
# Datas ajoutées pour la ville : Vouillé-les-Marais
# Datas ajoutées pour la ville : Vouvant
# Datas ajoutées pour la ville : Xanton-Chassenon

# %%
df_error_url = pd.DataFrame(error_data)
df_meilleur_agent_PdlL = pd.DataFrame(all_data)

# %%
df_meilleur_agent_PdlL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 512 entries, 0 to 511
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ville                  512 non-null    object
#  1   prix_appartement       512 non-null    float64
#  2   min_appartement        512 non-null    float64
#  3   max_appartement        512 non-null    float64
#  4   prix_maison            512 non-null    float64
#  5   min_maison             512 non-null    float64
#  6   max_maison             512 non-null    float64
#  7   loyer_appartement      512 non-null    float64
#  8   loyer_min_appartement  512 non-null    float64
#  9   loyer_max_appartement  512 non-null    float64
#  10  loyer_maison           497 non-null    float64
#  11  loyer_min_maison       497 non-null    float64
#  12  loyer_max_maison       497 non-null    float64
#  13  url                    512 non-null    object
#  14  Code_insee             512 non-null    object
# dtypes: float64(12), object(3)
# memory usage: 60.1+ KB

# %%
print(df_meilleur_agent_PdlL.shape)
print(df_error_url.shape)
# Out:
# (512, 15)
# (60, 2)

# %%
df_duplicate = df_meilleur_agent5.drop_duplicates(subset=['ville'])

# %%
df_meilleur_agent_PdlL.to_csv('ma_2.csv',index=False)
df_error_url.to_csv('error_ma_2.csv',index=False)

# %%
df_meilleur_agent9['ratio_appt'] = round((df_meilleur_agent9['prix_appartement'] / df_meilleur_agent9['loyer_appartement']),1)

df_meilleur_agent9['ratio_maison'] = round((df_meilleur_agent9['prix_maison'] / df_meilleur_agent9['loyer_maison']),1)

df_meilleur_agent9 = df_meilleur_agent9.sort_values('ratio_appt')
